# %%
import pandas as pd

df_vendas = pd.read_excel('DATABASES\Vendas2.xlsx')
df_estados = pd.read_excel('DATABASES\Estados.xlsx')
df_filiais = pd.read_excel('DATABASES\Filiais.xlsx')
df_grupos = pd.read_excel('DATABASES\Grupos.xlsx')
print('Importações realizadas com sucesso!')

data_atual = df_vendas['EMISSAO'].max()
df_vendas_dia = {}

df_vendas_dia = df_vendas.loc[df_vendas['EMISSAO'] == data_atual].copy()
df_vendas_dia['VAL_SALDO'] = df_vendas_dia['VALOR_CIF']-df_vendas_dia['VAL_DEV']-df_vendas_dia['DESCONTO']-df_vendas_dia['FRETE']
print('DataFrames criados!')
print(data_atual)
# Out:
# Importações realizadas com sucesso!
# DataFrames criados!
# 2021-11-15 00:00:00

# %%
import locale

cell_hover = {  # for row hover use <tr> instead of <td>
    'selector': 'td:hover',
    'props': [('background-color', '#ffffb3')]
}
index_names = {
    'selector': '.index_name',
    'props': 'font-style: italic; color: darkgrey; font-weight:normal;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000066; color: white;'
}

locale.setlocale(locale.LC_NUMERIC, 'pt_br.utf-8')
pd.set_option('display.float_format', lambda x: locale.format_string('%.2f', x, grouping=True))

emp_fat = df_vendas_dia['EMP_FAT'].unique()
emp_fat.sort()
print(emp_fat)

for emp in emp_fat:
    df_01 = df_vendas_dia.loc[df_vendas_dia['EMP_FAT'] == emp].copy()
    df_01 = df_01[['FINALID', 'FINALIDADE', 'ITEM', 'DESC_ITEM','QTD_CX', 'PESO','PRECO_CIF', 'VALOR_CIF', 'DESCONTO', 'FRT_UNIT', 'FRETE','FRETE VDJ', 'VALOR_FOB', 'PRECO_FOB','QTD_DEV', 'VAL_DEV', 'QTD_SALDO', 'VAL_SALDO', 'ICMS TRIB', 'PIS TRIB','COFINS TRIB']]
    df_01 = df_01.groupby(['FINALID', 'FINALIDADE', 'ITEM', 'DESC_ITEM']).\
        agg(QTD_CAIXA=('QTD_CX','sum'),PESO=('PESO','sum'),\
        PRECO_MEDIO=('PRECO_CIF','mean'),VALOR_CIF=('VALOR_CIF','sum'),\
        DESCONTO=('DESCONTO','sum'),FRETE=('FRETE','sum'),\
        VALOR_FOB=('VALOR_FOB','sum'),PRECO_FOB=('PRECO_FOB','mean'),\
        PRECO_MAX=('PRECO_FOB','max'),PRECO_MIN=('PRECO_FOB','min'),\
        QTD_DEV=('QTD_DEV','sum'),VAL_DEV=('VAL_DEV','sum'),\
        QTD_SALDO=('QTD_SALDO','sum'),VAL_SALDO=('VAL_SALDO','sum'),\
        ICMS_TRIB=('ICMS TRIB','sum'),PIS_TRIB=('PIS TRIB','sum'),COFINS_TRIB=('COFINS TRIB','sum'))
    display(df_01)
    df_01.to_html('Faturamento Diário\Empresa {} - {}-{}-{}.html'.format(emp, data_atual.day, data_atual.month, data_atual.year))
print('Exportações concluídas!')
# Out:
# [ 1  5  7 11 12 17 18 40 41]
#                                                                                                                                 QTD_CAIXA  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...       1400
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...       5400
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                              18900
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...       3780
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                          57250
#                                                             GRX.003         VISCERAS IN NATURA                                      63549
#                                                             GRX.013         RETALHOS DE CMS                                         23201
#
#                                                                                                                                      PESO  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...  28.000,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...  54.000,00
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                         189.000,00
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...  75.600,00
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                      57.250,00
#                                                             GRX.003         VISCERAS IN NATURA                                  63.549,00
#                                                             GRX.013         RETALHOS DE CMS                                     23.201,00
#
#                                                                                                                                 PRECO_MEDIO  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...         7,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...        20,05
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                                17,88
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...         5,41
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                             0,05
#                                                             GRX.003         VISCERAS IN NATURA                                         0,17
#                                                             GRX.013         RETALHOS DE CMS                                            0,15
#
#                                                                                                                                   VALOR_CIF  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...   196.000,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS... 1.082.896,02
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                         3.380.391,63
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...   409.744,44
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                         2.862,50
#                                                             GRX.003         VISCERAS IN NATURA                                    10.803,33
#                                                             GRX.013         RETALHOS DE CMS                                        3.480,15
#
#                                                                                                                                 DESCONTO  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...      0,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...      0,00
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                              0,00
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...      0,00
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                          0,00
#                                                             GRX.003         VISCERAS IN NATURA                                      0,00
#                                                             GRX.013         RETALHOS DE CMS                                         0,00
#
#                                                                                                                                    FRETE  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA... 22.116,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...      0,00
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                              0,00
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...      0,00
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                          0,00
#                                                             GRX.003         VISCERAS IN NATURA                                      0,00
#                                                             GRX.013         RETALHOS DE CMS                                         0,00
#
#                                                                                                                                   VALOR_FOB  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...   173.884,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS... 1.082.896,02
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                         3.380.391,63
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...   409.744,44
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                         2.862,50
#                                                             GRX.003         VISCERAS IN NATURA                                    10.803,33
#                                                             GRX.013         RETALHOS DE CMS                                        3.480,15
#
#                                                                                                                                 PRECO_FOB  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...       6,21
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...      20,05
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                              17,89
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...       5,42
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                           0,05
#                                                             GRX.003         VISCERAS IN NATURA                                       0,17
#                                                             GRX.013         RETALHOS DE CMS                                          0,15
#
#                                                                                                                                 PRECO_MAX  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...       6,21
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...      20,05
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                              17,89
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...       5,42
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                           0,05
#                                                             GRX.003         VISCERAS IN NATURA                                       0,17
#                                                             GRX.013         RETALHOS DE CMS                                          0,15
#
#                                                                                                                                 PRECO_MIN  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...       6,21
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...      20,05
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                              17,89
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...       5,42
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                           0,05
#                                                             GRX.003         VISCERAS IN NATURA                                       0,17
#                                                             GRX.013         RETALHOS DE CMS                                          0,15
#
#                                                                                                                                 QTD_DEV  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...     0,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...     0,00
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                             0,00
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...     0,00
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                         0,00
#                                                             GRX.003         VISCERAS IN NATURA                                     0,00
#                                                             GRX.013         RETALHOS DE CMS                                        0,00
#
#                                                                                                                                 VAL_DEV  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...     0,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...     0,00
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                             0,00
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...     0,00
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                         0,00
#                                                             GRX.003         VISCERAS IN NATURA                                     0,00
#                                                             GRX.013         RETALHOS DE CMS                                        0,00
#
#                                                                                                                                 QTD_SALDO  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...  28.000,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...  54.000,00
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                         189.000,00
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...  75.600,00
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                      57.250,00
#                                                             GRX.003         VISCERAS IN NATURA                                  63.549,00
#                                                             GRX.013         RETALHOS DE CMS                                     23.201,00
#
#                                                                                                                                   VAL_SALDO  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...   173.884,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS... 1.082.896,02
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                         3.380.391,63
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...   409.744,44
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                         2.862,50
#                                                             GRX.003         VISCERAS IN NATURA                                    10.803,33
#                                                             GRX.013         RETALHOS DE CMS                                        3.480,15
#
#                                                                                                                                 ICMS_TRIB  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...  13.720,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...       0,00
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                               0,00
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...       0,00
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                           0,00
#                                                             GRX.003         VISCERAS IN NATURA                                       0,00
#                                                             GRX.013         RETALHOS DE CMS                                        243,61
#
#                                                                                                                                 PIS_TRIB  \
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...      0,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...      0,00
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                              0,00
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...      0,00
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                         47,23
#                                                             GRX.003         VISCERAS IN NATURA                                    178,25
#                                                             GRX.013         RETALHOS DE CMS                                         0,00
#
#                                                                                                                                 COFINS_TRIB
# FINALID  FINALIDADE                                         ITEM            DESC_ITEM
# A - MI   A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...         0,00
# B - ME   C - VENDAS MERCADO EXTERNO                     ... EXP.E201        CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OSS...         0,00
#                                                             EXP.E223        FRANGO DESOSSADO CONGELADO                                 0,00
#                                                             EXP.E49         CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE (...         0,00
# G - SBP. K - VENDAS FFO                                     GRX.002         PENA IN NATURA                                           217,55
#                                                             GRX.003         VISCERAS IN NATURA                                       821,05
#                                                             GRX.013         RETALHOS DE CMS                                            0,00
#                                                                              QTD_CAIXA  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH      29260
#
#                                                                                  PESO  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH 29.260,00
#
#                                                                              PRECO_MEDIO  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH         6,80
#
#                                                                              VALOR_CIF  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH 198.968,00
#
#                                                                              DESCONTO  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH      0,00
#
#                                                                              FRETE  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH   0,00
#
#                                                                              VALOR_FOB  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH 198.968,00
#
#                                                                              PRECO_FOB  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH       6,80
#
#                                                                              PRECO_MAX  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH       6,80
#
#                                                                              PRECO_MIN  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH       6,80
#
#                                                                              QTD_DEV  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH     0,00
#
#                                                                              VAL_DEV  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH     0,00
#
#                                                                              QTD_SALDO  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH  29.260,00
#
#                                                                              VAL_SALDO  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH 198.968,00
#
#                                                                              ICMS_TRIB  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH  23.876,16
#
#                                                                              PIS_TRIB  \
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH  1.138,10
#
#                                                                              COFINS_TRIB
# FINALID  FINALIDADE     ITEM            DESC_ITEM
# G - SBP. K - VENDAS FFO GRX.FLA         FARINHA DE VISCERAS DE AVES LOW ASH     5.252,76
#                                                                                                                                QTD_CAIXA  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL...       3890
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                              21
#
#                                                                                                                                    PESO  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL... 70.020,00
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                         389,60
#
#                                                                                                                                PRECO_MEDIO  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL...         8,55
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                             10,00
#
#                                                                                                                                VALOR_CIF  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL... 598.671,00
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                        3.896,00
#
#                                                                                                                                DESCONTO  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL... 59.867,10
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                         233,76
#
#                                                                                                                                   FRETE  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL... 37.110,60
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                         206,49
#
#                                                                                                                                VALOR_FOB  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL... 537.613,55
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                        3.689,51
#
#                                                                                                                                PRECO_FOB  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL...       7,68
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                            9,47
#
#                                                                                                                                PRECO_MAX  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL...       7,68
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                            9,47
#
#                                                                                                                                PRECO_MIN  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL...       7,68
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                            9,47
#
#                                                                                                                                QTD_DEV  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL...     0,00
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                          0,00
#
#                                                                                                                                VAL_DEV  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL...     0,00
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                          0,00
#
#                                                                                                                                QTD_SALDO  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL...  70.020,00
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                          389,60
#
#                                                                                                                                VAL_SALDO  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL... 501.693,30
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                        3.455,75
#
#                                                                                                                                ICMS_TRIB  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL...  41.906,98
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                            0,00
#
#                                                                                                                                PIS_TRIB  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL...      0,00
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                          64,28
#
#                                                                                                                                COFINS_TRIB
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# D - SP  B - VENDAS GRANDES REDES                       ... 100.A143        CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUAL...         0,00
#         I - VENDAS FILIAL S?O PAULO                    ... 30S.002         APRESUNTADO PARA FATIAR 10X11                            296,10
#                                                                                                   QTD_CAIXA  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO          0
#
#                                                                                                       PESO  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO 15.910,00
#
#                                                                                                   PRECO_MEDIO  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO         0,60
#
#                                                                                                   VALOR_CIF  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO   9.546,00
#
#                                                                                                   DESCONTO  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO      0,00
#
#                                                                                                   FRETE  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO   0,00
#
#                                                                                                   VALOR_FOB  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO   9.546,00
#
#                                                                                                   PRECO_FOB  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO       0,60
#
#                                                                                                   PRECO_MAX  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO       0,60
#
#                                                                                                   PRECO_MIN  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO       0,60
#
#                                                                                                   QTD_DEV  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO     0,00
#
#                                                                                                   VAL_DEV  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO     0,00
#
#                                                                                                   QTD_SALDO  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO  15.910,00
#
#                                                                                                   VAL_SALDO  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO   9.546,00
#
#                                                                                                   ICMS_TRIB  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO     668,22
#
#                                                                                                   PIS_TRIB  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO      0,00
#
#                                                                                                   COFINS_TRIB
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... OVO.000.007     OVO LIQUIDO         0,00
#                                                                                                                                QTD_CAIXA  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...       1400
#
#                                                                                                                                    PESO  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA... 28.000,00
#
#                                                                                                                                PRECO_MEDIO  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...         6,50
#
#                                                                                                                                VALOR_CIF  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA... 182.000,00
#
#                                                                                                                                DESCONTO  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...      0,00
#
#                                                                                                                                FRETE  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...   0,00
#
#                                                                                                                                VALOR_FOB  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA... 182.000,00
#
#                                                                                                                                PRECO_FOB  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...       6,50
#
#                                                                                                                                PRECO_MAX  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...       6,50
#
#                                                                                                                                PRECO_MIN  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...       6,50
#
#                                                                                                                                QTD_DEV  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...     0,00
#
#                                                                                                                                VAL_DEV  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...     0,00
#
#                                                                                                                                QTD_SALDO  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...  28.000,00
#
#                                                                                                                                VAL_SALDO  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA... 182.000,00
#
#                                                                                                                                ICMS_TRIB  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# A - MI  A - VENDAS MERCADO INTERNO                     ... 200.R918        CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOXA...  12.739,99
#
#                                                                                                                                PIS_TRIB  \
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# ...
# B - ME  C - VENDAS MERCADO EXTERNO                     ... EXP.S73         FRANGO DESOSSADO CONGELADO - SHAWARMA                   0,00
# E - GTB A - VENDAS MERCADO INTERNO                     ... 200.S212        COXA E SOBRECOXA C/ PORCAO DORSAL CONGELADA IND...      0,00
#                                                            200.S218        COXA E SOBRECOXA CONGELADA INDIVIDUAL CX PP 20 ...      0,00
#                                                            400.S498        CORTES CONGELADOS DE FRANGO - PEITO SEM OSSO SE...      0,00
#         R - VENDAS FILIAL GTB                              100.S160        COXINHA DA ASA CONGELADA INDIVIDUAL CX PP 20 KG...      0,00
#                                                            200.S212        COXA E SOBRECOXA C/ PORCAO DORSAL CONGELADA IND...      0,00
#                                                            200.S218        COXA E SOBRECOXA CONGELADA INDIVIDUAL CX PP 20 ...      0,00
#                                                            300.S341        SAMBIQUIRA CONGELADA PACOTE CX PP 20 KG (SUBLIME)       0,00
#                                                            400.S490        CORTES CONGELADOS DE FRANGO - FILEZINHO SASSAMI         0,00
#                                                            400.S498        CORTES CONGELADOS DE FRANGO - PEITO SEM OSSO SE...      0,00
#
#                                                                                                                                COFINS_TRIB
# FINALID FINALIDADE                                         ITEM            DESC_ITEM
# B - ME  C - VENDAS MERCADO EXTERNO                     ... EXP.S73         FRANGO DESOSSADO CONGELADO - SHAWARMA                      0,00
# E - GTB A - VENDAS MERCADO INTERNO                     ... 200.S212        COXA E SOBRECOXA C/ PORCAO DORSAL CONGELADA IND...         0,00
#                                                            200.S218        COXA E SOBRECOXA CONGELADA INDIVIDUAL CX PP 20 ...         0,00
#                                                            400.S498        CORTES CONGELADOS DE FRANGO - PEITO SEM OSSO SE...         0,00
#         R - VENDAS FILIAL GTB                              100.S160        COXINHA DA ASA CONGELADA INDIVIDUAL CX PP 20 KG...         0,00
#                                                            200.S212        COXA E SOBRECOXA C/ PORCAO DORSAL CONGELADA IND...         0,00
#                                                            200.S218        COXA E SOBRECOXA CONGELADA INDIVIDUAL CX PP 20 ...         0,00
#                                                            300.S341        SAMBIQUIRA CONGELADA PACOTE CX PP 20 KG (SUBLIME)          0,00
#                                                            400.S490        CORTES CONGELADOS DE FRANGO - FILEZINHO SASSAMI            0,00
#                                                            400.S498        CORTES CONGELADOS DE FRANGO - PEITO SEM OSSO SE...         0,00
#                                                                                                                  QTD_CAIXA  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL          0
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA           0
#                                                                      SUC.000.004     SUCATA DE SACARIA                   0
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)                     0
#
#                                                                                                                     PESO  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL    70,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA    380,00
#                                                                      SUC.000.004     SUCATA DE SACARIA            280,00
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)            1.070,00
#
#                                                                                                                  PRECO_MEDIO  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL         4,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA          1,00
#                                                                      SUC.000.004     SUCATA DE SACARIA                  1,50
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)                    0,95
#
#                                                                                                                  VALOR_CIF  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL     280,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA      380,00
#                                                                      SUC.000.004     SUCATA DE SACARIA              420,00
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)              1.042,00
#
#                                                                                                                  DESCONTO  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL      0,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA       0,00
#                                                                      SUC.000.004     SUCATA DE SACARIA               0,00
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)                 0,00
#
#                                                                                                                  FRETE  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL   0,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA    0,00
#                                                                      SUC.000.004     SUCATA DE SACARIA            0,00
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)              0,00
#
#                                                                                                                  VALOR_FOB  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL     280,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA      380,00
#                                                                      SUC.000.004     SUCATA DE SACARIA              420,00
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)              1.042,00
#
#                                                                                                                  PRECO_FOB  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL       4,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA        1,00
#                                                                      SUC.000.004     SUCATA DE SACARIA                1,50
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)                  0,95
#
#                                                                                                                  PRECO_MAX  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL       4,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA        1,00
#                                                                      SUC.000.004     SUCATA DE SACARIA                1,50
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)                  1,00
#
#                                                                                                                  PRECO_MIN  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL       4,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA        1,00
#                                                                      SUC.000.004     SUCATA DE SACARIA                1,50
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)                  0,80
#
#                                                                                                                  QTD_DEV  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL     0,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA      0,00
#                                                                      SUC.000.004     SUCATA DE SACARIA              0,00
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)                0,00
#
#                                                                                                                  VAL_DEV  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL     0,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA      0,00
#                                                                      SUC.000.004     SUCATA DE SACARIA              0,00
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)                0,00
#
#                                                                                                                  QTD_SALDO  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL      70,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA      380,00
#                                                                      SUC.000.004     SUCATA DE SACARIA              280,00
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)              1.070,00
#
#                                                                                                                  VAL_SALDO  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL     280,00
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA      380,00
#                                                                      SUC.000.004     SUCATA DE SACARIA              420,00
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)              1.042,00
#
#                                                                                                                  ICMS_TRIB  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL      47,60
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA       64,60
#                                                                      SUC.000.004     SUCATA DE SACARIA               71,40
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)                  0,00
#
#                                                                                                                  PIS_TRIB  \
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL      3,83
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA       5,20
#                                                                      SUC.000.004     SUCATA DE SACARIA               5,75
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)                 0,00
#
#                                                                                                                  COFINS_TRIB
# FINALID           FINALIDADE                                         ITEM            DESC_ITEM
# H - OUTRAS VENDAS M - OUTRAS VENDAS                              ... MUC.200.929     PALETE MADEIRA DESCARTAVEL        17,66
#                                                                      SUC.000.002     SUCATA EMBALAGEM PLASTICA         23,97
#                                                                      SUC.000.004     SUCATA DE SACARIA                 26,49
# J - OUTRAS        A - VENDAS MERCADO INTERNO                     ... RAC.000.001     MILHO (RESIDUO)                    0,00
# Exportações concluídas!

# %%
import codecs
empresas = emp_fat

#Relatório de itens por empresa

for i, empresa in enumerate(empresas):
    i = codecs.open('Faturamento Diário\Empresa {} - {}-{}-{}.html'.format(empresa, data_atual.day, data_atual.month, data_atual.year), encoding='utf-8').read()
    formato_html = (f'''
    <!DOCTYPE html>
    <head>
    <html lang="pt-br">
    <meta charset="UTF-8">
    <meta http-equiv="X-UA-Compatible" content="IE=edge">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Faturamento</title>
      <style>
        body {{
          font-family: Arial, sans-serif;
          color: rgba(0,0,0,1);
        }}

        h1 {{
            font-family: Arial, Helvetica, sans-serif;
            font-size: 25px;
            margin: 5px;
            background-color: #bbb;
            color: black;
            text-align: center;
            padding: 5px;
        }}

        .dataframe tr:nth-child(even) {{
            background-color: #ddd;
        }}

        .dataframe td {{
            border: 1px solid #606060;
            padding: 10px;
            font-size: 10pt;
            text-align: right;
            vertical-align: middle;
        }}

        .dataframe thead {{
            border: 1px solid #606060;
            padding: 10px;
            font-size: 10pt;
            text-align: right;
            vertical-align: middle;
        }}

        .dataframe tbody {{
            border: 1px solid #606060;
            padding: 5px;
            font-size: 10pt;
            text-align: center;
            vertical-align: middle;
        }}

         .dataframe th {{
            border: 1px solid #606060;
            padding: 5px;
            font-size: 10pt;
            text-align: left;
            vertical-align: middle;
            valign:"center";
        }}

        .dataframe {{
            width: 21cm;
            min-height: 29.7cm;
            padding: 0.2cm;
            margin: 0.1cm auto;
            border: 1px #D3D3D3 solid;
            border-radius: 2px;
            background: white;
            box-shadow: 0 0 2px rgba(0, 0, 0, 0.1);
            border: 1px solid #606060;
            border-spacing: 0px;
            width: 100%;
            text-align: right;
        }}

      </style>
    </head>
    <h1>
    Empresa  {empresa:0.0f} - {data_atual.day}-{data_atual.month}-{data_atual.year}
    </h1>
    {i}
    ''')
    with open('Faturamento Por Empresa\Empresa {} - {}-{}-{}.html'.format(empresa, data_atual.day, data_atual.month, data_atual.year), 'w', encoding='utf-8') as arquivo:
        print(formato_html, file=arquivo)
print('Arquivos Gerados!')
# Out:
# Arquivos Gerados!

# %% [markdown]
# # Teste de agrupamento
# ## Não rodar

# %%
import pandas as pd

for emp in emp_fat:
    df_01 = df_vendas_dia.loc[df_vendas_dia['EMP_FAT'] == emp].copy()
    df_01 = df_01[['FINALID', 'FINALIDADE', 'ITEM', 'DESC_ITEM','QTD_CX', 'PESO','PRECO_CIF', 'VALOR_CIF', 'DESCONTO', 'FRT_UNIT', 'FRETE','FRETE VDJ', 'VALOR_FOB', 'PRECO_FOB','QTD_DEV', 'VAL_DEV', 'QTD_SALDO', 'VAL_SALDO', 'ICMS TRIB', 'PIS TRIB','COFINS TRIB']]
    df_01['FINALIDADE'] = df_01['FINALIDADE'].str.strip()  ##para remover espaços em branco ao final da finalidade
    df_01 = df_01.groupby(['FINALID', 'FINALIDADE', 'ITEM', 'DESC_ITEM'],as_index=False).\
            agg(QTD_CAIXA=('QTD_CX','sum'),PESO=('PESO','sum'),\
            PRECO_MEDIO=('PRECO_CIF','mean'),VALOR_CIF=('VALOR_CIF','sum'),\
            DESCONTO=('DESCONTO','sum'),FRETE=('FRETE','sum'),\
            VALOR_FOB=('VALOR_FOB','sum'),PRECO_FOB=('PRECO_FOB','mean'),\
            PRECO_MAX=('PRECO_FOB','max'),PRECO_MIN=('PRECO_FOB','min'),\
            QTD_DEV=('QTD_DEV','sum'),VAL_DEV=('VAL_DEV','sum'),\
            QTD_SALDO=('QTD_SALDO','sum'),VAL_SALDO=('VAL_SALDO','sum'),\
            ICMS_TRIB=('ICMS TRIB','sum'),PIS_TRIB=('PIS TRIB','sum'),COFINS_TRIB=('COFINS TRIB','sum'))
    #print(emp)
    #display(df_01)
    df_01['ITEM'] = df_01['ITEM'].astype(str)
    df_01.sort_values('ITEM')
    df_02 =  pd.concat([df_01,df_01.groupby(['FINALID', 'FINALIDADE'],as_index=False).agg(QTD_CAIXA=('QTD_CAIXA','sum'),PESO=('PESO','sum'),\
            PRECO_MEDIO=('PRECO_MEDIO','mean'),VALOR_CIF=('VALOR_CIF','sum'),\
            DESCONTO=('DESCONTO','sum'),FRETE=('FRETE','sum'),\
            VALOR_FOB=('VALOR_FOB','sum'),PRECO_FOB=('PRECO_FOB','mean'),\
            PRECO_MAX=('PRECO_FOB','max'),PRECO_MIN=('PRECO_FOB','min'),\
            QTD_DEV=('QTD_DEV','sum'),VAL_DEV=('VAL_DEV','sum'),\
            QTD_SALDO=('QTD_SALDO','sum'),VAL_SALDO=('VAL_SALDO','sum'),\
            ICMS_TRIB=('ICMS_TRIB','sum'),PIS_TRIB=('PIS_TRIB','sum'),COFINS_TRIB=('COFINS_TRIB','sum'))]).sort_values(['FINALID', 'FINALIDADE'])
    #print(df_02)
    df_02.loc[df_02['ITEM'].isnull(), 'FINALIDADE'] = 'Subtotal'
    display(df_02.fillna(''))
    df_02.fillna('').to_html('Faturamento Diário\Empresa {} - {}-{}-{}.html'.format(emp, data_atual.day, data_atual.month, data_atual.year))


print('Exportações concluídas!')
# Out:
#     FINALID                  FINALIDADE             ITEM  \
# 0    A - MI  A - VENDAS MERCADO INTERNO  200.R918
# 0    A - MI                    Subtotal
# 1    B - ME  C - VENDAS MERCADO EXTERNO  EXP.E201
# 2    B - ME  C - VENDAS MERCADO EXTERNO  EXP.E223
# 3    B - ME  C - VENDAS MERCADO EXTERNO  EXP.E49
# 1    B - ME                    Subtotal
# 4  G - SBP.              K - VENDAS FFO  GRX.002
# 5  G - SBP.              K - VENDAS FFO  GRX.003
# 6  G - SBP.              K - VENDAS FFO  GRX.013
# 2  G - SBP.                    Subtotal
#
#                                            DESC_ITEM  QTD_CAIXA       PESO  \
# 0  CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOX...       1400  28.000,00
# 0                                                          1400  28.000,00
# 1  CORTES CONGELADOS DE FRANGO (MEIO PEITO SEM OS...       5400  54.000,00
# 2                         FRANGO DESOSSADO CONGELADO      18900 189.000,00
# 3  CARNE MECANICAMENTE SEPARADA CONGELADA DE AVE ...       3780  75.600,00
# 1                                                         28080 318.600,00
# 4                                     PENA IN NATURA      57250  57.250,00
# 5                                 VISCERAS IN NATURA      63549  63.549,00
# 6                                    RETALHOS DE CMS      23201  23.201,00
# 2                                                        144000 144.000,00
#
#    PRECO_MEDIO    VALOR_CIF  DESCONTO     FRETE  ...  PRECO_FOB  PRECO_MAX  \
# 0         7,00   196.000,00      0,00 22.116,00  ...       6,21       6,21
# 0         7,00   196.000,00      0,00 22.116,00  ...       6,21       6,21
# 1        20,05 1.082.896,02      0,00      0,00  ...      20,05      20,05
# 2        17,88 3.380.391,63      0,00      0,00  ...      17,89      17,89
# 3         5,41   409.744,44      0,00      0,00  ...       5,42       5,42
# 1        14,45 4.873.032,09      0,00      0,00  ...      14,45      20,05
# 4         0,05     2.862,50      0,00      0,00  ...       0,05       0,05
# 5         0,17    10.803,33      0,00      0,00  ...       0,17       0,17
# 6         0,15     3.480,15      0,00      0,00  ...       0,15       0,15
# 2         0,12    17.145,98      0,00      0,00  ...       0,12       0,17
#
#    PRECO_MIN  QTD_DEV  VAL_DEV  QTD_SALDO    VAL_SALDO  ICMS_TRIB  PIS_TRIB  \
# 0       6,21     0,00     0,00  28.000,00   173.884,00  13.720,00      0,00
# 0       6,21     0,00     0,00  28.000,00   173.884,00  13.720,00      0,00
# 1      20,05     0,00     0,00  54.000,00 1.082.896,02       0,00      0,00
# 2      17,89     0,00     0,00 189.000,00 3.380.391,63       0,00      0,00
# 3       5,42     0,00     0,00  75.600,00   409.744,44       0,00      0,00
# 1       5,42     0,00     0,00 318.600,00 4.873.032,09       0,00      0,00
# 4       0,05     0,00     0,00  57.250,00     2.862,50       0,00     47,23
# 5       0,17     0,00     0,00  63.549,00    10.803,33       0,00    178,25
# 6       0,15     0,00     0,00  23.201,00     3.480,15     243,61      0,00
# 2       0,05     0,00     0,00 144.000,00    17.145,98     243,61    225,48
#
#    COFINS_TRIB
# 0         0,00
# 0         0,00
# 1         0,00
# 2         0,00
# 3         0,00
# 1         0,00
# 4       217,55
# 5       821,05
# 6         0,00
# 2     1.038,60
#
# [10 rows x 21 columns]
#     FINALID      FINALIDADE             ITEM  \
# 0  G - SBP.  K - VENDAS FFO  GRX.FLA
# 0  G - SBP.        Subtotal
#
#                              DESC_ITEM  QTD_CAIXA      PESO  PRECO_MEDIO  \
# 0  FARINHA DE VISCERAS DE AVES LOW ASH      29260 29.260,00         6,80
# 0                                           29260 29.260,00         6,80
#
#    VALOR_CIF  DESCONTO  FRETE  ...  PRECO_FOB  PRECO_MAX  PRECO_MIN  QTD_DEV  \
# 0 198.968,00      0,00   0,00  ...       6,80       6,80       6,80     0,00
# 0 198.968,00      0,00   0,00  ...       6,80       6,80       6,80     0,00
#
#    VAL_DEV  QTD_SALDO  VAL_SALDO  ICMS_TRIB  PIS_TRIB  COFINS_TRIB
# 0     0,00  29.260,00 198.968,00  23.876,16  1.138,10     5.252,76
# 0     0,00  29.260,00 198.968,00  23.876,16  1.138,10     5.252,76
#
# [2 rows x 21 columns]
#   FINALID                   FINALIDADE             ITEM  \
# 0  D - SP     B - VENDAS GRANDES REDES  100.A143
# 0  D - SP                     Subtotal
# 1  D - SP  I - VENDAS FILIAL S?O PAULO  30S.002
# 1  D - SP                     Subtotal
#
#                                            DESC_ITEM  QTD_CAIXA      PESO  \
# 0  CORTES CONGELADOS DE FRANGO (ASAS) - INDIVIDUA...       3890 70.020,00
# 0                                                          3890 70.020,00
# 1                      APRESUNTADO PARA FATIAR 10X11         21    389,60
# 1                                                            21    389,60
#
#    PRECO_MEDIO  VALOR_CIF  DESCONTO     FRETE  ...  PRECO_FOB  PRECO_MAX  \
# 0         8,55 598.671,00 59.867,10 37.110,60  ...       7,68       7,68
# 0         8,55 598.671,00 59.867,10 37.110,60  ...       7,68       7,68
# 1        10,00   3.896,00    233,76    206,49  ...       9,47       9,47
# 1        10,00   3.896,00    233,76    206,49  ...       9,47       9,47
#
#    PRECO_MIN  QTD_DEV  VAL_DEV  QTD_SALDO  VAL_SALDO  ICMS_TRIB  PIS_TRIB  \
# 0       7,68     0,00     0,00  70.020,00 501.693,30  41.906,98      0,00
# 0       7,68     0,00     0,00  70.020,00 501.693,30  41.906,98      0,00
# 1       9,47     0,00     0,00     389,60   3.455,75       0,00     64,28
# 1       9,47     0,00     0,00     389,60   3.455,75       0,00     64,28
#
#    COFINS_TRIB
# 0         0,00
# 0         0,00
# 1       296,10
# 1       296,10
#
# [4 rows x 21 columns]
#              FINALID         FINALIDADE             ITEM    DESC_ITEM  \
# 0  H - OUTRAS VENDAS  M - OUTRAS VENDAS  OVO.000.007      OVO LIQUIDO
# 0  H - OUTRAS VENDAS           Subtotal
#
#    QTD_CAIXA      PESO  PRECO_MEDIO  VALOR_CIF  DESCONTO  FRETE  ...  \
# 0          0 15.910,00         0,60   9.546,00      0,00   0,00  ...
# 0          0 15.910,00         0,60   9.546,00      0,00   0,00  ...
#
#    PRECO_FOB  PRECO_MAX  PRECO_MIN  QTD_DEV  VAL_DEV  QTD_SALDO  VAL_SALDO  \
# 0       0,60       0,60       0,60     0,00     0,00  15.910,00   9.546,00
# 0       0,60       0,60       0,60     0,00     0,00  15.910,00   9.546,00
#
#    ICMS_TRIB  PIS_TRIB  COFINS_TRIB
# 0     668,22      0,00         0,00
# 0     668,22      0,00         0,00
#
# [2 rows x 21 columns]
#   FINALID                  FINALIDADE             ITEM  \
# 0  A - MI  A - VENDAS MERCADO INTERNO  200.R918
# 0  A - MI                    Subtotal
#
#                                            DESC_ITEM  QTD_CAIXA      PESO  \
# 0  CORTES CONGELADOS DE FRANGO - COXAS E SOBRECOX...       1400 28.000,00
# 0                                                          1400 28.000,00
#
#    PRECO_MEDIO  VALOR_CIF  DESCONTO  FRETE  ...  PRECO_FOB  PRECO_MAX  \
# 0         6,50 182.000,00      0,00   0,00  ...       6,50       6,50
# 0         6,50 182.000,00      0,00   0,00  ...       6,50       6,50
#
#    PRECO_MIN  QTD_DEV  VAL_DEV  QTD_SALDO  VAL_SALDO  ICMS_TRIB  PIS_TRIB  \
# 0       6,50     0,00     0,00  28.000,00 182.000,00  12.739,99      0,00
# 0       6,50     0,00     0,00  28.000,00 182.000,00  12.739,99      0,00
#
#    COFINS_TRIB
# 0         0,00
# 0         0,00
#
# [2 rows x 21 columns]
#       FINALID                  FINALIDADE             ITEM  \
# 0     C - SJP    B - VENDAS GRANDES REDES  20S.002
# 0     C - SJP                    Subtotal
# 1  J - OUTRAS  A - VENDAS MERCADO INTERNO  10S.001
# 2  J - OUTRAS  A - VENDAS MERCADO INTERNO  20S.004
# 3  J - OUTRAS  A - VENDAS MERCADO INTERNO  20S.006
# 4  J - OUTRAS  A - VENDAS MERCADO INTERNO  20S.008
# 5  J - OUTRAS  A - VENDAS MERCADO INTERNO  20S.013
# 6  J - OUTRAS  A - VENDAS MERCADO INTERNO  40S.001
# 7  J - OUTRAS  A - VENDAS MERCADO INTERNO  40S.003
# 8  J - OUTRAS  A - VENDAS MERCADO INTERNO  40S.007
# 9  J - OUTRAS  A - VENDAS MERCADO INTERNO  50S.001
# 1  J - OUTRAS                    Subtotal
#
#                                 DESC_ITEM  QTD_CAIXA      PESO  PRECO_MEDIO  \
# 0           LINGUICA TIPO CALABRESA 2,5KG       1274 12.740,00        12,50
# 0                                               1274 12.740,00        12,50
# 1          LINGUICA TOSCANA CONGELADA 5KG         10    100,00        11,50
# 2                         BACON MANTA 4KG         77    924,00        17,98
# 3                  BACON EM CUBOS  6X1 KG         20    120,00        17,00
# 4  BACON SEM PELE FATIADO 10X(700G)   7KG         20    140,00        21,39
# 5            BACON MANTA PEDACO (+/- 1KG)         42    498,90        17,50
# 6                APRESUNTADO FATIADO 150G          3      9,00        20,06
# 7            PRESUNTO COZIDO FATIADO 150G          4     12,00        22,66
# 8       SALAME TIPO ITALIANO FATIADO 100G         60    120,00        38,71
# 9       SALAME TIPO ITALIANO INTEIRO 400G          7     34,50         9,90
# 1                                                243  1.958,40        19,63
#
#    VALOR_CIF  DESCONTO  FRETE  ...  PRECO_FOB  PRECO_MAX  PRECO_MIN  QTD_DEV  \
# 0 159.250,00  1.592,50   0,00  ...      12,50      12,50      12,50     0,00
# 0 159.250,00  1.592,50   0,00  ...      12,50      12,50      12,50     0,00
# 1   1.150,00      0,00   0,00  ...      11,50      11,50      11,50     0,00
# 2  16.613,52      0,00   0,00  ...      17,98      17,98      17,98     0,00
# 3   2.040,00      0,00   0,00  ...      17,00      17,00      17,00     0,00
# 4   2.994,60      0,00   0,00  ...      21,39      21,39      21,39     0,00
# 5   8.731,63      0,00   0,00  ...      17,50      17,50      17,50     0,00
# 6     180,54      0,00   0,00  ...      20,06      20,06      20,06     0,00
# 7     271,92      0,00   0,00  ...      22,66      22,66      22,66     0,00
# 8   4.462,00      0,00   0,00  ...      38,71      41,00      36,42     0,00
# 9     341,68      0,00   0,00  ...       9,90       9,90       9,90     0,00
# 1  36.785,89      0,00   0,00  ...      19,63      38,71       9,90     0,00
#
#    VAL_DEV  QTD_SALDO  VAL_SALDO  ICMS_TRIB  PIS_TRIB  COFINS_TRIB
# 0     0,00  12.740,00 157.657,50  11.147,50  2.443,70    11.255,80
# 0     0,00  12.740,00 157.657,50  11.147,50  2.443,70    11.255,80
# 1     0,00     100,00   1.150,00      80,50     17,65        81,28
# 2     0,00     924,00  16.613,52   1.162,94      0,00         0,00
# 3     0,00     120,00   2.040,00     142,80      0,00         0,00
# 4     0,00     140,00   2.994,60     209,62      0,00         0,00
# 5     0,00     498,95   8.731,63     611,21      0,00         0,00
# 6     0,00       9,00     180,54      12,64      2,77        12,76
# 7     0,00      12,00     271,92      32,63      3,95        18,19
# 8     0,00     120,00   4.462,00     535,44     64,79       298,42
# 9     0,00      34,51     341,68      41,00      4,96        22,85
# 1     0,00   1.958,46  36.785,89   2.828,78     94,12       433,50
#
# [12 rows x 21 columns]
#   FINALID                  FINALIDADE             ITEM  \
# 0  A - MI  A - VENDAS MERCADO INTERNO  300.R330
# 1  A - MI  A - VENDAS MERCADO INTERNO  700.R932
# 0  A - MI                    Subtotal
#
#                                            DESC_ITEM  QTD_CAIXA      PESO  \
# 0  CARNE MECANICAMENTE  SEPARADA CONGELADA DE AVE...        600 12.000,00
# 1  FRANGO CONGELADO (COM 2 PES, 2 FIGADOS, 2 MOEL...       1400 28.000,00
# 0                                                          2000 40.000,00
#
#    PRECO_MEDIO  VALOR_CIF  DESCONTO  FRETE  ...  PRECO_FOB  PRECO_MAX  \
# 0         4,35  52.200,00      0,00   0,00  ...       4,35       4,35
# 1         6,90 193.200,00      0,00   0,00  ...       6,90       6,90
# 0         5,62 245.400,00      0,00   0,00  ...       5,62       6,90
#
#    PRECO_MIN  QTD_DEV  VAL_DEV  QTD_SALDO  VAL_SALDO  ICMS_TRIB  PIS_TRIB  \
# 0       4,35     0,00     0,00  12.000,00  52.200,00   3.654,00      0,00
# 1       6,90     0,00     0,00  28.000,00 193.200,00  13.523,99      0,00
# 0       4,35     0,00     0,00  40.000,00 245.400,00  17.177,99      0,00
#
#    COFINS_TRIB
# 0         0,00
# 1         0,00
# 0         0,00
#
# [3 rows x 21 columns]
#    FINALID                  FINALIDADE             ITEM  \
# 0   B - ME  C - VENDAS MERCADO EXTERNO  EXP.S73
# 0   B - ME                    Subtotal
# 1  E - GTB  A - VENDAS MERCADO INTERNO  200.S212
# 2  E - GTB  A - VENDAS MERCADO INTERNO  200.S218
# 3  E - GTB  A - VENDAS MERCADO INTERNO  400.S498
# 1  E - GTB                    Subtotal
# 4  E - GTB       R - VENDAS FILIAL GTB  100.S160
# 5  E - GTB       R - VENDAS FILIAL GTB  200.S212
# 6  E - GTB       R - VENDAS FILIAL GTB  200.S218
# 7  E - GTB       R - VENDAS FILIAL GTB  300.S341
# 8  E - GTB       R - VENDAS FILIAL GTB  400.S490
# 9  E - GTB       R - VENDAS FILIAL GTB  400.S498
# 2  E - GTB                    Subtotal
#
#                                            DESC_ITEM  QTD_CAIXA      PESO  \
# 0              FRANGO DESOSSADO CONGELADO - SHAWARMA       2700 27.000,00
# 0                                                          2700 27.000,00
# 1  COXA E SOBRECOXA C/ PORCAO DORSAL CONGELADA IN...        200  4.000,00
# 2  COXA E SOBRECOXA CONGELADA INDIVIDUAL CX PP 20...        600 12.000,00
# 3  CORTES CONGELADOS DE FRANGO - PEITO SEM OSSO S...       1400 28.000,00
# 1                                                          2200 44.000,00
# 4  COXINHA DA ASA CONGELADA INDIVIDUAL CX PP 20 K...        300  6.000,00
# 5  COXA E SOBRECOXA C/ PORCAO DORSAL CONGELADA IN...        490  9.800,00
# 6  COXA E SOBRECOXA CONGELADA INDIVIDUAL CX PP 20...         45    900,00
# 7  SAMBIQUIRA CONGELADA PACOTE CX PP 20 KG (SUBLIME)         30    600,00
# 8    CORTES CONGELADOS DE FRANGO - FILEZINHO SASSAMI         28    560,00
# 9  CORTES CONGELADOS DE FRANGO - PEITO SEM OSSO S...        500 10.000,00
# 2                                                          1393 27.860,00
#
#    PRECO_MEDIO  VALOR_CIF  DESCONTO  FRETE  ...  PRECO_FOB  PRECO_MAX  \
# 0        13,00 351.209,52      0,00   0,00  ...      13,01      13,01
# 0        13,00 351.209,52      0,00   0,00  ...      13,01      13,01
# 1         6,20  24.800,00      0,00   0,00  ...       6,20       6,20
# 2         6,60  79.200,00      0,00   0,00  ...       6,60       6,60
# 3        12,45 348.600,00      0,00   0,00  ...      12,45      12,45
# 1         8,42 452.600,00      0,00   0,00  ...       8,42      12,45
# 4         8,70  52.200,00      0,00   0,00  ...       8,70       8,70
# 5         6,11  59.800,00      0,00   0,00  ...       6,11       6,20
# 6         7,20   6.480,00      0,00   0,00  ...       7,20       7,20
# 7         4,40   2.640,00      0,00   0,00  ...       4,40       4,40
# 8        13,20   7.392,00      0,00   0,00  ...      13,20      13,20
# 9        12,60 126.000,00      0,00   0,00  ...      12,60      12,60
# 2         8,70 254.512,00      0,00   0,00  ...       8,70      13,20
#
#    PRECO_MIN  QTD_DEV  VAL_DEV  QTD_SALDO  VAL_SALDO  ICMS_TRIB  PIS_TRIB  \
# 0      13,01     0,00     0,00  27.000,00 351.209,52       0,00      0,00
# 0      13,01     0,00     0,00  27.000,00 351.209,52       0,00      0,00
# 1       6,20     0,00     0,00   4.000,00  24.800,00   1.735,99      0,00
# 2       6,60     0,00     0,00  12.000,00  79.200,00   5.543,97      0,00
# 3      12,45     0,00     0,00  28.000,00 348.600,00  24.401,86      0,00
# 1       6,20     0,00     0,00  44.000,00 452.600,00  31.681,82      0,00
# 4       8,70     0,00     0,00   6.000,00  52.200,00   3.653,98      0,00
# 5       6,10     0,00     0,00   9.800,00  59.800,00   4.186,00      0,00
# 6       7,20     0,00     0,00     900,00   6.480,00     453,60      0,00
# 7       4,40     0,00     0,00     600,00   2.640,00     184,80      0,00
# 8      13,20     0,00     0,00     560,00   7.392,00     517,44      0,00
# 9      12,60     0,00     0,00  10.000,00 126.000,00   8.819,95      0,00
# 2       4,40     0,00     0,00  27.860,00 254.512,00  17.815,77      0,00
#
#    COFINS_TRIB
# 0         0,00
# 0         0,00
# 1         0,00
# 2         0,00
# 3         0,00
# 1         0,00
# 4         0,00
# 5         0,00
# 6         0,00
# 7         0,00
# 8         0,00
# 9         0,00
# 2         0,00
#
# [13 rows x 21 columns]
#              FINALID                  FINALIDADE             ITEM  \
# 0  H - OUTRAS VENDAS           M - OUTRAS VENDAS  MUC.200.929
# 1  H - OUTRAS VENDAS           M - OUTRAS VENDAS  SUC.000.002
# 2  H - OUTRAS VENDAS           M - OUTRAS VENDAS  SUC.000.004
# 0  H - OUTRAS VENDAS                    Subtotal
# 3         J - OUTRAS  A - VENDAS MERCADO INTERNO  RAC.000.001
# 1         J - OUTRAS                    Subtotal
#
#                     DESC_ITEM  QTD_CAIXA     PESO  PRECO_MEDIO  VALOR_CIF  \
# 0  PALETE MADEIRA DESCARTAVEL          0    70,00         4,00     280,00
# 1   SUCATA EMBALAGEM PLASTICA          0   380,00         1,00     380,00
# 2           SUCATA DE SACARIA          0   280,00         1,50     420,00
# 0                                      0   730,00         2,17   1.080,00
# 3             MILHO (RESIDUO)          0 1.070,00         0,95   1.042,00
# 1                                      0 1.070,00         0,95   1.042,00
#
#    DESCONTO  FRETE  ...  PRECO_FOB  PRECO_MAX  PRECO_MIN  QTD_DEV  VAL_DEV  \
# 0      0,00   0,00  ...       4,00       4,00       4,00     0,00     0,00
# 1      0,00   0,00  ...       1,00       1,00       1,00     0,00     0,00
# 2      0,00   0,00  ...       1,50       1,50       1,50     0,00     0,00
# 0      0,00   0,00  ...       2,17       4,00       1,00     0,00     0,00
# 3      0,00   0,00  ...       0,95       1,00       0,80     0,00     0,00
# 1      0,00   0,00  ...       0,95       0,95       0,95     0,00     0,00
#
#    QTD_SALDO  VAL_SALDO  ICMS_TRIB  PIS_TRIB  COFINS_TRIB
# 0      70,00     280,00      47,60      3,83        17,66
# 1     380,00     380,00      64,60      5,20        23,97
# 2     280,00     420,00      71,40      5,75        26,49
# 0     730,00   1.080,00     183,60     14,78        68,12
# 3   1.070,00   1.042,00       0,00      0,00         0,00
# 1   1.070,00   1.042,00       0,00      0,00         0,00
#
# [6 rows x 21 columns]
# Exportações concluídas!
